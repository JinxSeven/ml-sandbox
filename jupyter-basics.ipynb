# %%
print("YHWH - King of universe")
# Out:
# YHWH - King of universe

# %%
import pandas as pd

# %%
hrt = pd.read_csv("./csvs/heart-disease.csv")

# %% [markdown]
# The table contains data from the CSV file read above.

# %%
hrt.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   60    1   3     145   233    1        0       150     0      2.3    0
# 1   35    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   55    1   1     120   236    0        1       178     0      0.8    2
# 4   56    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
hrt.age.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='age'>

# %%
import matplotlib.pyplot as plt

# %%
ls
# Out:
#  Volume in drive D is Local Disk
#  Volume Serial Number is C8BB-1F8C
#
#  Directory of D:\Development\JinxSeven\ml-sandbox
#
# 14-11-2025  11.24 AM    <DIR>          .
# 14-11-2025  11.24 AM    <DIR>          ..
# 29-10-2025  08.46 PM    <DIR>          .env
# 31-10-2025  01.42 PM                24 .gitignore
# 12-11-2025  09.37 PM    <DIR>          .ipynb_checkpoints
# 12-11-2025  09.08 PM    <DIR>          101
# 12-11-2025  09.16 PM    <DIR>          csvs
# 14-11-2025  11.27 AM             7,585 jupyter-basics.ipynb
# 14-11-2025  11.24 AM            55,899 Pandas.ipynb
#                3 File(s)         63,508 bytes
#                6 Dir(s)  34,722,603,008 bytes free
