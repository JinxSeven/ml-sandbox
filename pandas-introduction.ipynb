# %%
import pandas as pd

# %%
names = pd.Series(['JinxSeven', 'LeoBerzerk', 'CtOS', 'NoMercy'])

# %%
score = pd.Series([80, 90, 75, 100, 20])

# %%
scoreboard = pd.DataFrame({'names': names, 'ranking': score})
scoreboard
# Out:
#         names  ranking
# 0   JinxSeven       80
# 1  LeoBerzerk       90
# 2        CtOS       75
# 3     NoMercy      100
# 4         NaN       20

# %%
scoreboard.ranking.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='ranking'>

# %%
scoreboard.to_csv('./csvs/scoreboard.csv') # add additional para index with false to remove the column 'Unnamed'

# %%
sb_csv = pd.read_csv('./csvs/scoreboard.csv')

# %%
sb_csv.head()
# Out:
#    Unnamed: 0       names  ranking
# 0           0   JinxSeven       80
# 1           1  LeoBerzerk       90
# 2           2        CtOS       75
# 3           3     NoMercy      100
# 4           4         NaN       20

# %%
sb_csv.dtypes
# Out:
# Unnamed: 0     int64
# names         object
# ranking        int64
# dtype: object

# %%
sb_csv.describe()
# Out:
#        Unnamed: 0     ranking
# count    5.000000    5.000000
# mean     2.000000   73.000000
# std      1.581139   31.144823
# min      0.000000   20.000000
# 25%      1.000000   75.000000
# 50%      2.000000   80.000000
# 75%      3.000000   90.000000
# max      4.000000  100.000000

# %%
score.sum()
# Out:
# np.int64(365)

# %%
car_sales_data = pd.read_csv('./csvs/car-sales.csv')

# %%
car_sales_data.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
gta_data = {
    "title": [
        "Grand Theft Auto",
        "Grand Theft Auto II",
        "Grand Theft Auto III",
        "Grand Theft Auto: Vice City",
        "Grand Theft Auto: San Andreas",
        "Grand Theft Auto: Liberty City Stories",
        "Grand Theft Auto: Vice City Stories",
        "Grand Theft Auto IV",
        "Grand Theft Auto: The Ballad of Gay Tony",
        "Grand Theft Auto: The Lost and Damned",
        "Grand Theft Auto V"
    ],
    "release_year": [
        1997,
        1999,
        2001,
        2002,
        2004,
        2005,
        2006,
        2008,
        2009,
        2009,
        2013
    ],
    "main_player": [
        "Claude Speed",
        "Claude Speed",
        "Claude",
        "Tommy Vercetti",
        "Carl 'CJ' Johnson",
        "Toni Cipriani",
        "Victor Vance",
        "Niko Bellic",
        "Luis Fernando Lopez",
        "Johnny Klebitz",
        "Michael De Santa, Franklin Clinton, Trevor Philips"
    ]
}

# %%
gta_df = pd.DataFrame(gta_data)

# %%
gta_df['release_year'].sum() # total of passed in column
# Out:
# np.int64(22053)

# %%
gta_df.index
# Out:
# RangeIndex(start=0, stop=11, step=1)

# %%
car_sales_data.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
gta_release_years = pd.Series(gta_df["release_year"])
gta_release_years
# Out:
# 0     1997
# 1     1999
# 2     2001
# 3     2002
# 4     2004
# 5     2005
# 6     2006
# 7     2008
# 8     2009
# 9     2009
# 10    2013
# Name: release_year, dtype: int64

# %% [markdown]
# ## Recollecting Concepts

# %% [markdown]
# Creating a DataFrame

# %%
birth_year = pd.Series([1998, 1999, 1999, 2002, 2004, 2005])

# %%
people = pd.Series(['Samuel', 'David', 'Thomas', 'Reshmi', 'Abinesh', 'Beryl'])

# %%
birthday_data = pd.DataFrame({'names': people, 'birth year': birth_year})

# %%
birthday_data.head()
# Out:
#      names  birth year
# 0   Samuel        1998
# 1    David        1999
# 2   Thomas        1999
# 3   Reshmi        2002
# 4  Abinesh        2004

# %%
birthday_data['birth year'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='birth year'>

# %%
birthday_data.describe()
# Out:
#         birth year
# count     6.000000
# mean   2001.166667
# std       2.926887
# min    1998.000000
# 25%    1999.000000
# 50%    2000.500000
# 75%    2003.500000
# max    2005.000000

# %% [markdown]
# # .loc and .iloc

# %%
car_sales_data.loc[1]
# Out:
# Make                 Honda
# Colour                 Red
# Odometer (KM)        87899
# Doors                    4
# Price            $5,000.00
# Name: 1, dtype: object

# %% [markdown]
# # Indexing

# %%
messy_index = pd.Series(['a', 'b', 'c'], index=[2, 4, 6])
messy_index
# Out:
# 2    a
# 4    b
# 6    c
# dtype: object

# %%
birthday_data.iloc[2]
# Out:
# names         Thomas
# birth year      1999
# Name: 2, dtype: object

# %% [markdown]
# # Pandas Boolean Indexing
#
# It's nothing but querying data with Pandas

# %%
car_sales_data[car_sales_data['Odometer (KM)'] <= 50000]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 6   Honda   Blue          45698      4   $7,500.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_data[car_sales_data['Colour'] == 'Black']
# Out:
#   Make Colour  Odometer (KM)  Doors       Price
# 3  BMW  Black          11179      5  $22,000.00

# %%
car_sales_data['Odometer (KM)'].min()
# Out:
# 11179

# %%
car_sales_data[car_sales_data['Odometer (KM)'] == car_sales_data['Odometer (KM)'].min()]
# Out:
#   Make Colour  Odometer (KM)  Doors       Price
# 3  BMW  Black          11179      5  $22,000.00
